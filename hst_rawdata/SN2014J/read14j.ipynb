# %%
from matplotlib.pyplot import xlabel
import matplotlib.pyplot as plt
import numpy as np
#import matplotlib.ticker as ticker
import statistics

from numpy.lib.function_base import append

# %%
wavelength1 = []
flux1 = []
fluxmean = []
wavelengthcompile = []
fluxcompile = []
uncertaintycompile = []
dataqualitycompile = []
dataquality1 = []
#for weighted mean
fluxmeangroup = []
weightsgroup = []
wavelength = []
wavelengthb = []
flux = []
fluxb = []
fluxc = []
dataquality = []
dataqualityb = []
#uncertainties for weights
uncertainty1 = []
uncertainty = []
uncertaintyb = []
count = 0
certainty = 0
#can have a string of spectra so once complete, it can run through it with all the files

# %%
filenames=['SN2014J_uv_20140126_1.dat', 'SN2014J_uv_20140128_1.dat', 'SN2014J_uv_20140130_1.dat', 'SN2014J_uv_20140201_1.dat', 'SN2014J_uv_20140204_1.dat', 'SN2014J_uv_20140208_1.dat', 'SN2014J_uv_20140210_1.dat', 'SN2014J_uv_20140213_1.dat', 'SN2014J_uv_20140216_1.dat', 'SN2014J_uv_20140226_1.dat']

# %%
files=['SN2014J_uv_20140201_1.dat','SN2014J_opt_20140201_1.dat']

# %%
for spectrum in files:
#open file1
    with open(spectrum, 'r') as f:
#get data
        for line in f:
            content = line.split()
            if len(content)==2:
                wavelength1.append(content[0])
                flux1.append(content[1])
            #isApple = True if fruit == 'Apple'
            #flux1.append(content[1]) if len==2 else print(content)

# %%
wavelength1 = [float(x) for x in wavelength1]
for x in wavelength1:
    wavelengthcompile.append(x)
flux1 = [float(x) for x in flux1]
for x in flux1:
    fluxcompile.append(x)
print(flux1)
print(wavelength1)
# Out:
# [0.0, -8.2847748e-13, -9.7370376e-15, -4.6153704e-14, 1.7546103e-14, 2.0208177e-15, 2.2105241e-15, -8.6719919e-15, -1.6484432e-14, -1.7483157e-15, 6.2795402e-15, -2.2506817e-15, -2.3027035e-15, 1.6775409e-15, -2.2932098e-15, -2.4574058e-15, -1.5171642e-15, -6.3558552e-16, 5.338873e-16, 6.0727312e-16, -1.9621558e-15, -1.4740923e-15, -1.3819737e-15, 1.0460505e-16, 2.7676581e-15, 7.8191808e-16, 1.9765175e-15, 3.8237375e-16, 4.2176431e-16, -5.6030711e-16, -1.2628407e-15, 8.2784087e-16, -1.2540378e-15, 6.1218062e-16, -2.7047522e-16, -1.0184902e-15, -1.1850512e-15, -7.2572592e-17, -8.8386692e-16, -1.17095e-15, -4.9831912e-16, -1.3825141e-16, -4.5769458e-17, 2.54672e-16, -5.7460735e-16, -1.1495026e-16, -7.3697499e-16, -1.6964183e-16, -2.0090232e-16, 4.8707719e-16, 7.4326876e-16, -4.0454299e-16, 8.2317011e-17, -9.7902963e-18, -7.8397756e-17, 1.0287973e-15, 4.6868456e-16, 4.0882092e-17, -2.860835e-16, 6.5476196e-17, 4.8707597e-16, -7.1160535e-17, 6.6493394e-16, 1.7109438e-16, -2.8528668e-16, 
# ...

# %%
plt.plot(wavelength1, flux1, 'r-', label = "SN2014J", alpha = 1, linewidth = .9)
plt.ylim([0,0.2E-13])
plt.xlim([2800,3100])
plt.legend()
#plt.savefig("before.png")
plt.show()
