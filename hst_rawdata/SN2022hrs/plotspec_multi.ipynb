# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
specdata1 = pd.read_csv("SN2022hrs_muv_20220422.4_50.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])

specdata2 = pd.read_csv("SN2022hrs_muv_20220426.3_20.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])

specdata3 = pd.read_csv("SN2022hrs_muv_20220506.9_20.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])

specdata4 = pd.read_csv("SN2022hrs_muv_20220514.9_20.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])


erpdata = pd.read_csv("../../original_spectra/SN2017erp_hst_20170629.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux","fluxerr"])

fedata = pd.read_csv("../../original_spectra/SN2011fe_2011-09-13_16-05-00_HST_STIS_HST-Ia.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux","fluxerr"])

#fesullivandata =pd.read_csv("/Users/supernova/Desktop/SN/github/UVSNIa/hst_rawdata/SN2011fe/SN2011fe_sullivan/ptf11kly_20110910.obs.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux","fluxerr"])


ccjdata = pd.read_csv("../../original_spectra/SN2016ccj_hst_20160514.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux","fluxerr"])





#print(specdata1["wave"])
# Out:
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_60654/1460189394.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   specdata1 = pd.read_csv("SN2022hrs_muv_20220422.4_50.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_60654/1460189394.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   specdata2 = pd.read_csv("SN2022hrs_muv_20220426.3_20.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_60654/1460189394.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# ...

# %%
plt.rcParams['figure.figsize'] = [15, 12]
plt.rcParams.update({'font.size': 22})

plt.plot(specdata1["wave"],specdata1["flux"], label='Apr 22', color='maroon')

plt.plot(specdata2["wave"],specdata2["flux"], label='Apr 26/27', color='red')

plt.plot(specdata3["wave"],specdata3["flux"], label='May 7', color='green')

plt.plot(specdata4["wave"],specdata4["flux"], label='May 15', color='blue')

plt.xlim([1600,6000])
plt.xlabel('Wavelength')
#plt.ylim([1.00*10.0**(-15.0),2.5*10.0**(-15.0)])


plt.ylabel('Flux')
plt.title(' ')
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = [15, 9]
plt.rcParams.update({'font.size': 22})

plt.plot(specdata1["wave"],specdata1["flux"], label='Apr 22', color='maroon')

plt.plot(specdata2["wave"],specdata2["flux"], label='Apr 26/27', color='red')

plt.plot(specdata3["wave"],specdata3["flux"], label='May 7', color='green')

plt.plot(specdata4["wave"],specdata4["flux"], label='May 15', color='blue')

plt.xlim([1600,6000])
plt.xlabel('Wavelength')
#plt.ylim([1.00*10.0**(-19.0),1.0*10.0**(-13.0)])
plt.yscale('log',base=10) 


plt.ylabel('Flux')
plt.title(' ')
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = [15, 9]
plt.rcParams.update({'font.size': 22})

#plt.plot(ccjdata["wave"]/(1.0+0.041),1000.0*ccjdata["flux"], label='2016ccj', color='purple', linewidth=2)

plt.plot(fedata["wave"]/(1.0+0.000804),fedata["flux"],  label='2011fe', color='blue', linewidth=2)

#plt.plot(fesullivandata["wave"]/(1.0+0.000804),fesullivandata["flux"],  label='2011fe', color='purple', linewidth=2)
# this was used to confirm that the spectra were in the observer frame

plt.plot(specdata2["wave"]/(1.0+0.0047),8.0*specdata2["flux"],  label='2022hrs', color='red', linewidth=2)

#plt.plot(erpdata["wave"]/(1.0+0.006174),erpdata["flux"], label='2017erp', color='green', linewidth=2)




plt.xlim([1600,6000])
plt.xlabel('Rest-Frame Wavelength')
#plt.ylim([1.00*10.0**(-19.0),1.0*10.0**(-13.0)])
plt.yscale('log',base=10) 


plt.ylabel('Flux')
plt.title(' ')
plt.legend(fontsize=48)
plt.show()

# %%
plt.rcParams['figure.figsize'] = [15, 9]
plt.rcParams.update({'font.size': 22})

#plt.plot(ccjdata["wave"]/(1.0+0.041),1000.0*ccjdata["flux"], label='2016ccj', color='purple', linewidth=2)

plt.plot(fedata["wave"]/(1.0+0.01),fedata["flux"]/2,  label='2011fe', color='blue', linewidth=2)

#plt.plot(fesullivandata["wave"]/(1.0+0.000804),fesullivandata["flux"],  label='2011fe', color='purple', linewidth=2)
# this was used to confirm that the spectra were in the observer frame

plt.plot(specdata2["wave"]/(1.0+0.0047),8.0*specdata2["flux"],  label='2022hrs', color='red', linewidth=2)

#plt.plot(erpdata["wave"]/(1.0+0.006174),erpdata["flux"], label='2017erp', color='green', linewidth=2)




plt.xlim([1600,6000])
plt.xlabel('Rest-Frame Wavelength')
#plt.ylim([1.00*10.0**(-19.0),1.0*10.0**(-13.0)])
plt.yscale('log',base=10) 


plt.ylabel('Flux')
plt.title(' ')
plt.legend(fontsize=48)
plt.show()

# %%
specdata2 = pd.read_csv("SN2022hrs_muv_20220422.4_2.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
specdata5 = pd.read_csv("SN2022hrs_muv_20220422.4_5.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
specdata10 = pd.read_csv("SN2022hrs_muv_20220422.4_10.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
specdata20 = pd.read_csv("SN2022hrs_muv_20220422.4_20.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
specdata30 = pd.read_csv("SN2022hrs_muv_20220422.4_30.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
specdata50 = pd.read_csv("SN2022hrs_muv_20220422.4_50.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])


plt.plot(specdata2["wave"]/(1.0+0.0047),8.0*specdata2["flux"],  label='2022hrs 2 A', color='grey', linewidth=2)
#plt.plot(specdata5["wave"]/(1.0+0.0047),8.0*specdata5["flux"],  label='2022hrs 5 A', color='red', linewidth=2)
#plt.plot(specdata10["wave"]/(1.0+0.0047),8.0*specdata10["flux"],  label='2022hrs 10 A', color='maroon', linewidth=2)
#plt.plot(specdata20["wave"]/(1.0+0.0047),8.0*specdata20["flux"],  label='2022hrs 20 A', color='black', linewidth=2)
#plt.plot(specdata30["wave"]/(1.0+0.0047),8.0*specdata30["flux"],  label='2022hrs 30 A', color='blue', linewidth=2)
#plt.plot(specdata50["wave"]/(1.0+0.0047),8.0*specdata50["flux"],  label='2022hrs 50 A', color='yellow', linewidth=2)





plt.xlim([2600,2900])
plt.xlabel('Rest-Frame Wavelength')
plt.ylim([1.00*10.0**(-16.0),4.0*10.0**(-13.0)])
plt.yscale('log',base=10) 


plt.ylabel('Flux')
plt.title(' ')
#plt.legend(fontsize=48)
plt.show()
# Out:
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_60654/2697949224.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   specdata2 = pd.read_csv("SN2022hrs_muv_20220422.4_2.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_60654/2697949224.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   specdata5 = pd.read_csv("SN2022hrs_muv_20220422.4_5.dat", delim_whitespace="True", header=None, comment='#', names=["wave","flux"])
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_60654/2697949224.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# ...
